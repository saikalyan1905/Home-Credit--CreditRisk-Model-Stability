# %% [markdown]
# # part - 1

# %%
! python /kaggle/usr/lib/part_1_py/part_1_py.py
# Out:
# ['amtinstpaidbefduel24m_4187115A', 'annuity_780A', 'annuitynextmonth_57A', 'avginstallast24m_3658937A', 'avglnamtstart24m_4525187A', 'avgoutstandbalancel6m_4187114A', 'avgpmtlast12m_4525200A', 'credamount_770A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'disbursedcredamount_1113A', 'downpmt_116A', 'inittransactionamount_650A', 'lastapprcommoditycat_1041M', 'lastapprcommoditytypec_5251766M', 'lastapprcredamount_781A', 'lastcancelreason_561M', 'lastotherinc_902A', 'lastotherlnsexpense_631A', 'lastrejectcommoditycat_161M', 'lastrejectcommodtypec_5251769M', 'lastrejectcredamount_222A', 'lastrejectreason_759M', 'lastrejectreasonclient_4145040M', 'maininc_215A', 'maxannuity_159A', 'maxannuity_4075009A', 'maxdebt4_972A', 'maxinstallast24m_3658928A', 'maxlnamtstart6m_4525199A', 'maxoutstandbalancel12m_4187113A', 'maxpmtlast3m_4525190A', 'previouscontdistrict_112M', 'price_1097A', 'sumoutstandtotal_3546847A', 'sumoutstandtotalest_4493215A', 'totaldebt_9A', 'totalsettled_863A', 'totinstallast1m_4525188A']
# ['description_5085714M', 'education_1103M', 'education_88M', 'maritalst_385M', 'maritalst_893M', 'pmtaverage_3A', 'pmtaverage_4527227A', 'pmtaverage_4955615A', 'pmtssum_45A']
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.691095
# [100]	valid_0's auc: 0.703953
# [150]	valid_0's auc: 0.711861
# [200]	valid_0's auc: 0.716831
# [250]	valid_0's auc: 0.721328
# [300]	valid_0's auc: 0.724977
# [350]	valid_0's auc: 0.72777
# [400]	valid_0's auc: 0.730175
# [450]	valid_0's auc: 0.731988
# [500]	valid_0's auc: 0.733342
# [550]	valid_0's auc: 0.734689
# [600]	valid_0's auc: 0.735962
# [650]	valid_0's auc: 0.737175
# [700]	valid_0's auc: 0.738054
# [750]	valid_0's auc: 0.738723
# [800]	valid_0's auc: 0.739336
# [850]	valid_0's auc: 0.739908
# [900]	valid_0's auc: 0.740675
# [950]	valid_0's auc: 0.741262
# [1000]	valid_0's auc: 0.741708
# [1050]	valid_0's auc: 0.742212
# [1100]	valid_0's auc: 0.742653
# [1150]	valid_0's auc: 0.743194
# [1200]	valid_0's auc: 0.743523
# [1250]	valid_0's auc: 0.744
# [1300]	valid_0's auc: 0.74439
# [1350]	valid_0's auc: 0.74486
# [1400]	valid_0's auc: 0.745177
# [1450]	valid_0's auc: 0.745474
# [1500]	valid_0's auc: 0.745891
# [1550]	valid_0's auc: 0.746096
# Early stopping, best iteration is:
# [1570]	valid_0's auc: 0.746273
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.690089
# [100]	valid_0's auc: 0.702615
# [150]	valid_0's auc: 0.71162
# [200]	valid_0's auc: 0.718568
# [250]	valid_0's auc: 0.723615
# [300]	valid_0's auc: 0.727692
# [350]	valid_0's auc: 0.730932
# [400]	valid_0's auc: 0.733463
# [450]	valid_0's auc: 0.735389
# [500]	valid_0's auc: 0.737004
# [550]	valid_0's auc: 0.738496
# [600]	valid_0's auc: 0.73987
# [650]	valid_0's auc: 0.740968
# [700]	valid_0's auc: 0.742093
# [750]	valid_0's auc: 0.74293
# [800]	valid_0's auc: 0.743832
# [850]	valid_0's auc: 0.744592
# [900]	valid_0's auc: 0.745284
# [950]	valid_0's auc: 0.745949
# [1000]	valid_0's auc: 0.746476
# [1050]	valid_0's auc: 0.746995
# [1100]	valid_0's auc: 0.747562
# [1150]	valid_0's auc: 0.747922
# [1200]	valid_0's auc: 0.748452
# [1250]	valid_0's auc: 0.748904
# [1300]	valid_0's auc: 0.749242
# [1350]	valid_0's auc: 0.749584
# [1400]	valid_0's auc: 0.749859
# [1450]	valid_0's auc: 0.750247
# [1500]	valid_0's auc: 0.750622
# [1550]	valid_0's auc: 0.750991
# [1600]	valid_0's auc: 0.751255
# Early stopping, best iteration is:
# [1610]	valid_0's auc: 0.751311
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.687868
# [100]	valid_0's auc: 0.700475
# [150]	valid_0's auc: 0.708739
# [200]	valid_0's auc: 0.715085
# [250]	valid_0's auc: 0.720334
# [300]	valid_0's auc: 0.724752
# [350]	valid_0's auc: 0.728033
# [400]	valid_0's auc: 0.7309
# [450]	valid_0's auc: 0.732834
# [500]	valid_0's auc: 0.734509
# [550]	valid_0's auc: 0.735863
# [600]	valid_0's auc: 0.736954
# [650]	valid_0's auc: 0.738091
# [700]	valid_0's auc: 0.739228
# [750]	valid_0's auc: 0.740139
# [800]	valid_0's auc: 0.740984
# [850]	valid_0's auc: 0.742038
# [900]	valid_0's auc: 0.742661
# [950]	valid_0's auc: 0.74343
# [1000]	valid_0's auc: 0.74415
# [1050]	valid_0's auc: 0.744678
# [1100]	valid_0's auc: 0.744941
# [1150]	valid_0's auc: 0.74527
# [1200]	valid_0's auc: 0.745885
# [1250]	valid_0's auc: 0.746223
# [1300]	valid_0's auc: 0.746557
# [1350]	valid_0's auc: 0.746964
# [1400]	valid_0's auc: 0.747382
# [1450]	valid_0's auc: 0.74772
# [1500]	valid_0's auc: 0.748047
# [1550]	valid_0's auc: 0.748372
# [1600]	valid_0's auc: 0.748612
# [1650]	valid_0's auc: 0.748919
# [1700]	valid_0's auc: 0.749072
# Early stopping, best iteration is:
# [1725]	valid_0's auc: 0.749189
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.698724
# [100]	valid_0's auc: 0.712025
# [150]	valid_0's auc: 0.719233
# [200]	valid_0's auc: 0.725453
# [250]	valid_0's auc: 0.730179
# [300]	valid_0's auc: 0.734438
# [350]	valid_0's auc: 0.737275
# [400]	valid_0's auc: 0.739965
# [450]	valid_0's auc: 0.742265
# [500]	valid_0's auc: 0.74415
# [550]	valid_0's auc: 0.745733
# [600]	valid_0's auc: 0.746949
# [650]	valid_0's auc: 0.74821
# [700]	valid_0's auc: 0.749308
# [750]	valid_0's auc: 0.750118
# [800]	valid_0's auc: 0.750791
# [850]	valid_0's auc: 0.751433
# [900]	valid_0's auc: 0.752208
# [950]	valid_0's auc: 0.752807
# [1000]	valid_0's auc: 0.753413
# [1050]	valid_0's auc: 0.754049
# [1100]	valid_0's auc: 0.754482
# [1150]	valid_0's auc: 0.75497
# [1200]	valid_0's auc: 0.755414
# [1250]	valid_0's auc: 0.75582
# [1300]	valid_0's auc: 0.75619
# [1350]	valid_0's auc: 0.756585
# [1400]	valid_0's auc: 0.756932
# [1450]	valid_0's auc: 0.757366
# [1500]	valid_0's auc: 0.757566
# [1550]	valid_0's auc: 0.757988
# Early stopping, best iteration is:
# [1565]	valid_0's auc: 0.758139
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.699624
# [100]	valid_0's auc: 0.711312
# [150]	valid_0's auc: 0.718174
# [200]	valid_0's auc: 0.723201
# [250]	valid_0's auc: 0.727798
# [300]	valid_0's auc: 0.731112
# [350]	valid_0's auc: 0.734205
# [400]	valid_0's auc: 0.736562
# [450]	valid_0's auc: 0.73873
# [500]	valid_0's auc: 0.74016
# [550]	valid_0's auc: 0.741709
# [600]	valid_0's auc: 0.742955
# [650]	valid_0's auc: 0.74407
# [700]	valid_0's auc: 0.745043
# [750]	valid_0's auc: 0.745819
# [800]	valid_0's auc: 0.746376
# [850]	valid_0's auc: 0.747204
# [900]	valid_0's auc: 0.7477
# [950]	valid_0's auc: 0.748295
# [1000]	valid_0's auc: 0.748957
# [1050]	valid_0's auc: 0.749672
# [1100]	valid_0's auc: 0.750298
# [1150]	valid_0's auc: 0.750671
# [1200]	valid_0's auc: 0.751209
# [1250]	valid_0's auc: 0.751578
# [1300]	valid_0's auc: 0.751964
# [1350]	valid_0's auc: 0.752342
# Early stopping, best iteration is:
# [1345]	valid_0's auc: 0.752349
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.54108
# [1]	validation_0-auc:0.55916
# [2]	validation_0-auc:0.57834
# [3]	validation_0-auc:0.58265
# [4]	validation_0-auc:0.58622
# [5]	validation_0-auc:0.59682
# [6]	validation_0-auc:0.59980
# [7]	validation_0-auc:0.60809
# [8]	validation_0-auc:0.60764
# [9]	validation_0-auc:0.61165
# [10]	validation_0-auc:0.61213
# [11]	validation_0-auc:0.60893
# [12]	validation_0-auc:0.61130
# [13]	validation_0-auc:0.61208
# [14]	validation_0-auc:0.61522
# [15]	validation_0-auc:0.61611
# [16]	validation_0-auc:0.61490
# [17]	validation_0-auc:0.61489
# [18]	validation_0-auc:0.61625
# [19]	validation_0-auc:0.62060
# [20]	validation_0-auc:0.62681
# [21]	validation_0-auc:0.62732
# [22]	validation_0-auc:0.62744
# [23]	validation_0-auc:0.62463
# [24]	validation_0-auc:0.62736
# [25]	validation_0-auc:0.62826
# [26]	validation_0-auc:0.63143
# [27]	validation_0-auc:0.63078
# [28]	validation_0-auc:0.63094
# [29]	validation_0-auc:0.63077
# [30]	validation_0-auc:0.63263
# [31]	validation_0-auc:0.62976
# [32]	validation_0-auc:0.63017
# [33]	validation_0-auc:0.62948
# [34]	validation_0-auc:0.62837
# [35]	validation_0-auc:0.62747
# [36]	validation_0-auc:0.63009
# [37]	validation_0-auc:0.62898
# [38]	validation_0-auc:0.62834
# [39]	validation_0-auc:0.62888
# [40]	validation_0-auc:0.62734
# [41]	validation_0-auc:0.62886
# [42]	validation_0-auc:0.62904
# [43]	validation_0-auc:0.62845
# [44]	validation_0-auc:0.62955
# [45]	validation_0-auc:0.63351
# [46]	validation_0-auc:0.63315
# [47]	validation_0-auc:0.63321
# [48]	validation_0-auc:0.63355
# [49]	validation_0-auc:0.63164
# [50]	validation_0-auc:0.63136
# [51]	validation_0-auc:0.62927
# [52]	validation_0-auc:0.63094
# [53]	validation_0-auc:0.63171
# [54]	validation_0-auc:0.63267
# [55]	validation_0-auc:0.63099
# [56]	validation_0-auc:0.63060
# [57]	validation_0-auc:0.63089
# [58]	validation_0-auc:0.63130
# [59]	validation_0-auc:0.63218
# [60]	validation_0-auc:0.63242
# [61]	validation_0-auc:0.63308
# [62]	validation_0-auc:0.63320
# [63]	validation_0-auc:0.63258
# [64]	validation_0-auc:0.63336
# [65]	validation_0-auc:0.63375
# [66]	validation_0-auc:0.63334
# [67]	validation_0-auc:0.63357
# [68]	validation_0-auc:0.63331
# [69]	validation_0-auc:0.63330
# [70]	validation_0-auc:0.63383
# [71]	validation_0-auc:0.63396
# [72]	validation_0-auc:0.63431
# [73]	validation_0-auc:0.63343
# [74]	validation_0-auc:0.63406
# [75]	validation_0-auc:0.63450
# [76]	validation_0-auc:0.63572
# [77]	validation_0-auc:0.63585
# [78]	validation_0-auc:0.63489
# [79]	validation_0-auc:0.63510
# [80]	validation_0-auc:0.63575
# [81]	validation_0-auc:0.63598
# [82]	validation_0-auc:0.63616
# [83]	validation_0-auc:0.63600
# [84]	validation_0-auc:0.63627
# [85]	validation_0-auc:0.63680
# [86]	validation_0-auc:0.63676
# [87]	validation_0-auc:0.63716
# [88]	validation_0-auc:0.63710
# [89]	validation_0-auc:0.63714
# [90]	validation_0-auc:0.63686
# [91]	validation_0-auc:0.63672
# [92]	validation_0-auc:0.63824
# [93]	validation_0-auc:0.63837
# [94]	validation_0-auc:0.63864
# [95]	validation_0-auc:0.63884
# [96]	validation_0-auc:0.63909
# [97]	validation_0-auc:0.63883
# [98]	validation_0-auc:0.63903
# [99]	validation_0-auc:0.63902
# [100]	validation_0-auc:0.63898
# [101]	validation_0-auc:0.63921
# [102]	validation_0-auc:0.63923
# [103]	validation_0-auc:0.63902
# [104]	validation_0-auc:0.63932
# [105]	validation_0-auc:0.64034
# [106]	validation_0-auc:0.64134
# [107]	validation_0-auc:0.64153
# [108]	validation_0-auc:0.64194
# [109]	validation_0-auc:0.64134
# [110]	validation_0-auc:0.64097
# [111]	validation_0-auc:0.64099
# [112]	validation_0-auc:0.64105
# [113]	validation_0-auc:0.64104
# [114]	validation_0-auc:0.64125
# [115]	validation_0-auc:0.64170
# [116]	validation_0-auc:0.64175
# [117]	validation_0-auc:0.64192
# [118]	validation_0-auc:0.64161
# [119]	validation_0-auc:0.64196
# [120]	validation_0-auc:0.64213
# [121]	validation_0-auc:0.64227
# [122]	validation_0-auc:0.64242
# [123]	validation_0-auc:0.64259
# [124]	validation_0-auc:0.64305
# [125]	validation_0-auc:0.64315
# [126]	validation_0-auc:0.64334
# [127]	validation_0-auc:0.64347
# [128]	validation_0-auc:0.64357
# [129]	validation_0-auc:0.64351
# [130]	validation_0-auc:0.64280
# [131]	validation_0-auc:0.64264
# [132]	validation_0-auc:0.64265
# [133]	validation_0-auc:0.64385
# [134]	validation_0-auc:0.64354
# [135]	validation_0-auc:0.64279
# [136]	validation_0-auc:0.64193
# [137]	validation_0-auc:0.64201
# [138]	validation_0-auc:0.64213
# [139]	validation_0-auc:0.64225
# [140]	validation_0-auc:0.64143
# [141]	validation_0-auc:0.64125
# [142]	validation_0-auc:0.64137
# [143]	validation_0-auc:0.64132
# [144]	validation_0-auc:0.64152
# [145]	validation_0-auc:0.64021
# [146]	validation_0-auc:0.64072
# [147]	validation_0-auc:0.64082
# [148]	validation_0-auc:0.64092
# [149]	validation_0-auc:0.64064
# [150]	validation_0-auc:0.64076
# [151]	validation_0-auc:0.64107
# [152]	validation_0-auc:0.64116
# [153]	validation_0-auc:0.64100
# [154]	validation_0-auc:0.63988
# [155]	validation_0-auc:0.63986
# [156]	validation_0-auc:0.63994
# [157]	validation_0-auc:0.63984
# [158]	validation_0-auc:0.63984
# [159]	validation_0-auc:0.63975
# [160]	validation_0-auc:0.63986
# [161]	validation_0-auc:0.63987
# [162]	validation_0-auc:0.63973
# [163]	validation_0-auc:0.63991
# [164]	validation_0-auc:0.63990
# [165]	validation_0-auc:0.64009
# [166]	validation_0-auc:0.64036
# [167]	validation_0-auc:0.64054
# [168]	validation_0-auc:0.64022
# [169]	validation_0-auc:0.63969
# [170]	validation_0-auc:0.63972
# [171]	validation_0-auc:0.63972
# [172]	validation_0-auc:0.63908
# [173]	validation_0-auc:0.63949
# [174]	validation_0-auc:0.63936
# [175]	validation_0-auc:0.63955
# [176]	validation_0-auc:0.63946
# [177]	validation_0-auc:0.63957
# [178]	validation_0-auc:0.63882
# [179]	validation_0-auc:0.63888
# [180]	validation_0-auc:0.63832
# [181]	validation_0-auc:0.63805
# [182]	validation_0-auc:0.63829
# [183]	validation_0-auc:0.63844
# [184]	validation_0-auc:0.63864
# [185]	validation_0-auc:0.63902
# [186]	validation_0-auc:0.63897
# [187]	validation_0-auc:0.63908
# [188]	validation_0-auc:0.63920
# [189]	validation_0-auc:0.63940
# [190]	validation_0-auc:0.63936
# [191]	validation_0-auc:0.63949
# [192]	validation_0-auc:0.63945
# [193]	validation_0-auc:0.63923
# [194]	validation_0-auc:0.63921
# [195]	validation_0-auc:0.63937
# [196]	validation_0-auc:0.63912
# [197]	validation_0-auc:0.63928
# [198]	validation_0-auc:0.63935
# [199]	validation_0-auc:0.63934
# [200]	validation_0-auc:0.63915
# [201]	validation_0-auc:0.63995
# [202]	validation_0-auc:0.63995
# [203]	validation_0-auc:0.63972
# [204]	validation_0-auc:0.63988
# [205]	validation_0-auc:0.63992
# [206]	validation_0-auc:0.64028
# [207]	validation_0-auc:0.64040
# [208]	validation_0-auc:0.64052
# [209]	validation_0-auc:0.64053
# [210]	validation_0-auc:0.64060
# [211]	validation_0-auc:0.64064
# [212]	validation_0-auc:0.64087
# [213]	validation_0-auc:0.64049
# [214]	validation_0-auc:0.64052
# [215]	validation_0-auc:0.64060
# [216]	validation_0-auc:0.64008
# [217]	validation_0-auc:0.64015
# [218]	validation_0-auc:0.64040
# [219]	validation_0-auc:0.64047
# [220]	validation_0-auc:0.64066
# [221]	validation_0-auc:0.64062
# [222]	validation_0-auc:0.64068
# [223]	validation_0-auc:0.64085
# [224]	validation_0-auc:0.64093
# [225]	validation_0-auc:0.64082
# [226]	validation_0-auc:0.64083
# [227]	validation_0-auc:0.64094
# [228]	validation_0-auc:0.64071
# [229]	validation_0-auc:0.64086
# [230]	validation_0-auc:0.64126
# [231]	validation_0-auc:0.64149
# [232]	validation_0-auc:0.64149
# [233]	validation_0-auc:0.64140
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	test: 0.6499358	best: 0.6499358 (0)	total: 11.7s	remaining: 3h 54m 5s
# 1:	total: 12.2s	remaining: 2h 1m 18s
# 2:	total: 12.2s	remaining: 1h 21m 9s
# 3:	total: 12.6s	remaining: 1h 2m 54s
# 4:	total: 13.1s	remaining: 52m 3s
# 5:	test: 0.6963289	best: 0.6963289 (5)	total: 13.5s	remaining: 44m 48s
# 6:	total: 14s	remaining: 39m 38s
# 7:	total: 14.4s	remaining: 35m 41s
# 8:	total: 14.8s	remaining: 32m 37s
# 9:	total: 14.9s	remaining: 29m 29s
# 10:	test: 0.7061742	best: 0.7061742 (10)	total: 15.3s	remaining: 27m 36s
# 11:	total: 15.8s	remaining: 26m 1s
# 12:	total: 16.1s	remaining: 24m 34s
# 13:	total: 16.6s	remaining: 23m 23s
# 14:	total: 17s	remaining: 22m 21s
# 15:	test: 0.7136814	best: 0.7136814 (15)	total: 17.4s	remaining: 21m 24s
# 16:	total: 17.8s	remaining: 20m 37s
# 17:	total: 18.2s	remaining: 19m 57s
# 18:	total: 18.7s	remaining: 19m 21s
# 19:	total: 19.1s	remaining: 18m 48s
# 20:	test: 0.7197005	best: 0.7197005 (20)	total: 19.6s	remaining: 18m 19s
# 21:	total: 20s	remaining: 17m 50s
# 22:	total: 20.4s	remaining: 17m 26s
# 23:	total: 20.9s	remaining: 17m 4s
# 24:	total: 21.3s	remaining: 16m 43s
# 25:	test: 0.7244724	best: 0.7244724 (25)	total: 21.8s	remaining: 16m 22s
# 26:	total: 22.2s	remaining: 16m 4s
# 27:	total: 22.6s	remaining: 15m 47s
# 28:	total: 23.1s	remaining: 15m 31s
# 29:	total: 23.5s	remaining: 15m 16s
# 30:	test: 0.7283099	best: 0.7283099 (30)	total: 24s	remaining: 15m 3s
# 31:	total: 24.4s	remaining: 14m 51s
# 32:	total: 24.9s	remaining: 14m 39s
# 33:	total: 25.3s	remaining: 14m 27s
# 34:	total: 25.7s	remaining: 14m 15s
# 35:	test: 0.7309636	best: 0.7309636 (35)	total: 26.1s	remaining: 14m 4s
# 36:	total: 26.5s	remaining: 13m 53s
# 37:	total: 27s	remaining: 13m 44s
# 38:	total: 27.4s	remaining: 13m 36s
# 39:	total: 27.9s	remaining: 13m 28s
# 40:	test: 0.7341509	best: 0.7341509 (40)	total: 28.3s	remaining: 13m 21s
# 41:	total: 28.8s	remaining: 13m 14s
# 42:	total: 29.3s	remaining: 13m 7s
# 43:	total: 29.7s	remaining: 13m
# 44:	total: 30.2s	remaining: 12m 54s
# 45:	test: 0.7356779	best: 0.7356779 (45)	total: 30.6s	remaining: 12m 48s
# 46:	total: 31.1s	remaining: 12m 42s
# 47:	total: 31.5s	remaining: 12m 35s
# 48:	total: 31.9s	remaining: 12m 30s
# 49:	total: 32.4s	remaining: 12m 24s
# 50:	test: 0.7376795	best: 0.7376795 (50)	total: 32.8s	remaining: 12m 19s
# 51:	total: 33.3s	remaining: 12m 14s
# 52:	total: 33.7s	remaining: 12m 9s
# 53:	total: 34.2s	remaining: 12m 4s
# 54:	total: 34.6s	remaining: 12m
# 55:	test: 0.7395994	best: 0.7395994 (55)	total: 35.1s	remaining: 11m 56s
# 56:	total: 35.5s	remaining: 11m 51s
# 57:	total: 35.9s	remaining: 11m 47s
# 58:	total: 36.4s	remaining: 11m 43s
# 59:	total: 36.8s	remaining: 11m 40s
# 60:	test: 0.7409217	best: 0.7409217 (60)	total: 37.3s	remaining: 11m 36s
# 61:	total: 37.7s	remaining: 11m 32s
# 62:	total: 38.2s	remaining: 11m 28s
# 63:	total: 38.6s	remaining: 11m 25s
# 64:	total: 39.1s	remaining: 11m 21s
# 65:	test: 0.7421019	best: 0.7421019 (65)	total: 39.5s	remaining: 11m 18s
# 66:	total: 39.9s	remaining: 11m 14s
# 67:	total: 40.3s	remaining: 11m 11s
# 68:	total: 40.8s	remaining: 11m 8s
# 69:	total: 41.2s	remaining: 11m 5s
# 70:	test: 0.7430972	best: 0.7430972 (70)	total: 41.7s	remaining: 11m 2s
# 71:	total: 42.1s	remaining: 10m 59s
# 72:	total: 42.5s	remaining: 10m 56s
# 73:	total: 42.9s	remaining: 10m 53s
# 74:	total: 43.4s	remaining: 10m 50s
# 75:	test: 0.7438196	best: 0.7438196 (75)	total: 43.8s	remaining: 10m 48s
# 76:	total: 44.3s	remaining: 10m 45s
# 77:	total: 44.7s	remaining: 10m 43s
# 78:	total: 45.2s	remaining: 10m 41s
# 79:	total: 45.6s	remaining: 10m 38s
# 80:	test: 0.7441285	best: 0.7441370 (79)	total: 46s	remaining: 10m 36s
# 81:	total: 46.5s	remaining: 10m 33s
# 82:	total: 46.9s	remaining: 10m 31s
# 83:	total: 47.4s	remaining: 10m 29s
# 84:	total: 47.8s	remaining: 10m 27s
# 85:	test: 0.7447014	best: 0.7447070 (84)	total: 48.2s	remaining: 10m 24s
# 86:	total: 48.6s	remaining: 10m 22s
# 87:	total: 49.1s	remaining: 10m 19s
# 88:	total: 49.5s	remaining: 10m 18s
# 89:	total: 50s	remaining: 10m 16s
# 90:	test: 0.7451922	best: 0.7451922 (90)	total: 50.4s	remaining: 10m 14s
# 91:	total: 50.8s	remaining: 10m 12s
# 92:	total: 51.3s	remaining: 10m 10s
# 93:	total: 51.6s	remaining: 10m 7s
# 94:	total: 52s	remaining: 10m 5s
# 95:	test: 0.7455711	best: 0.7455711 (95)	total: 52.5s	remaining: 10m 3s
# 96:	total: 52.9s	remaining: 10m 1s
# 97:	total: 53.3s	remaining: 9m 59s
# 98:	total: 53.7s	remaining: 9m 57s
# 99:	total: 54.2s	remaining: 9m 55s
# 100:	test: 0.7461142	best: 0.7461142 (100)	total: 54.6s	remaining: 9m 54s
# 101:	total: 55.1s	remaining: 9m 52s
# 102:	total: 55.5s	remaining: 9m 50s
# 103:	total: 55.9s	remaining: 9m 49s
# 104:	total: 56.4s	remaining: 9m 47s
# 105:	test: 0.7465164	best: 0.7465164 (105)	total: 56.8s	remaining: 9m 46s
# 106:	total: 57.3s	remaining: 9m 44s
# 107:	total: 57.7s	remaining: 9m 43s
# 108:	total: 58.1s	remaining: 9m 41s
# 109:	total: 58.6s	remaining: 9m 40s
# 110:	test: 0.7466070	best: 0.7467327 (109)	total: 59s	remaining: 9m 38s
# 111:	total: 59.5s	remaining: 9m 37s
# 112:	total: 59.9s	remaining: 9m 36s
# 113:	total: 1m	remaining: 9m 34s
# 114:	total: 1m	remaining: 9m 33s
# 115:	test: 0.7471703	best: 0.7471911 (114)	total: 1m 1s	remaining: 9m 32s
# 116:	total: 1m 1s	remaining: 9m 30s
# 117:	total: 1m 2s	remaining: 9m 29s
# 118:	total: 1m 2s	remaining: 9m 28s
# 119:	total: 1m 2s	remaining: 9m 26s
# 120:	test: 0.7475086	best: 0.7475086 (120)	total: 1m 3s	remaining: 9m 25s
# 121:	total: 1m 3s	remaining: 9m 24s
# 122:	total: 1m 4s	remaining: 9m 22s
# 123:	total: 1m 4s	remaining: 9m 21s
# 124:	total: 1m 5s	remaining: 9m 20s
# 125:	test: 0.7481852	best: 0.7481852 (125)	total: 1m 5s	remaining: 9m 18s
# 126:	total: 1m 5s	remaining: 9m 17s
# 127:	total: 1m 6s	remaining: 9m 16s
# 128:	total: 1m 6s	remaining: 9m 15s
# 129:	total: 1m 7s	remaining: 9m 13s
# 130:	test: 0.7485956	best: 0.7485956 (130)	total: 1m 7s	remaining: 9m 12s
# 131:	total: 1m 8s	remaining: 9m 11s
# 132:	total: 1m 8s	remaining: 9m 10s
# 133:	total: 1m 9s	remaining: 9m 9s
# 134:	total: 1m 9s	remaining: 9m 8s
# 135:	test: 0.7489932	best: 0.7490128 (133)	total: 1m 9s	remaining: 9m 6s
# 136:	total: 1m 10s	remaining: 9m 5s
# 137:	total: 1m 10s	remaining: 9m 4s
# 138:	total: 1m 11s	remaining: 9m 3s
# 139:	total: 1m 11s	remaining: 9m 2s
# 140:	test: 0.7492808	best: 0.7492831 (139)	total: 1m 12s	remaining: 9m 1s
# 141:	total: 1m 12s	remaining: 9m
# 142:	total: 1m 12s	remaining: 8m 59s
# 143:	total: 1m 13s	remaining: 8m 58s
# 144:	total: 1m 13s	remaining: 8m 57s
# 145:	test: 0.7495209	best: 0.7495864 (143)	total: 1m 14s	remaining: 8m 56s
# 146:	total: 1m 14s	remaining: 8m 55s
# 147:	total: 1m 15s	remaining: 8m 54s
# 148:	total: 1m 15s	remaining: 8m 53s
# 149:	total: 1m 16s	remaining: 8m 52s
# 150:	test: 0.7496693	best: 0.7497054 (149)	total: 1m 16s	remaining: 8m 51s
# 151:	total: 1m 16s	remaining: 8m 50s
# 152:	total: 1m 17s	remaining: 8m 49s
# 153:	total: 1m 17s	remaining: 8m 48s
# 154:	total: 1m 18s	remaining: 8m 47s
# 155:	test: 0.7500517	best: 0.7500587 (154)	total: 1m 18s	remaining: 8m 46s
# 156:	total: 1m 19s	remaining: 8m 45s
# 157:	total: 1m 19s	remaining: 8m 44s
# 158:	total: 1m 20s	remaining: 8m 43s
# 159:	total: 1m 20s	remaining: 8m 42s
# 160:	test: 0.7503434	best: 0.7503434 (160)	total: 1m 20s	remaining: 8m 42s
# 161:	total: 1m 21s	remaining: 8m 41s
# 162:	total: 1m 21s	remaining: 8m 40s
# 163:	total: 1m 22s	remaining: 8m 39s
# 164:	total: 1m 22s	remaining: 8m 38s
# 165:	test: 0.7504769	best: 0.7504911 (164)	total: 1m 23s	remaining: 8m 37s
# 166:	total: 1m 23s	remaining: 8m 36s
# 167:	total: 1m 24s	remaining: 8m 36s
# 168:	total: 1m 24s	remaining: 8m 35s
# 169:	total: 1m 24s	remaining: 8m 34s
# 170:	test: 0.7507759	best: 0.7507759 (170)	total: 1m 25s	remaining: 8m 33s
# 171:	total: 1m 25s	remaining: 8m 32s
# 172:	total: 1m 26s	remaining: 8m 31s
# 173:	total: 1m 26s	remaining: 8m 31s
# 174:	total: 1m 27s	remaining: 8m 30s
# 175:	test: 0.7507317	best: 0.7507759 (170)	total: 1m 27s	remaining: 8m 29s
# 176:	total: 1m 28s	remaining: 8m 28s
# 177:	total: 1m 28s	remaining: 8m 27s
# 178:	total: 1m 28s	remaining: 8m 26s
# 179:	total: 1m 29s	remaining: 8m 26s
# 180:	test: 0.7508363	best: 0.7508363 (180)	total: 1m 29s	remaining: 8m 25s
# 181:	total: 1m 30s	remaining: 8m 24s
# 182:	total: 1m 30s	remaining: 8m 24s
# 183:	total: 1m 31s	remaining: 8m 23s
# 184:	total: 1m 31s	remaining: 8m 22s
# 185:	test: 0.7509413	best: 0.7509630 (183)	total: 1m 32s	remaining: 8m 21s
# 186:	total: 1m 32s	remaining: 8m 20s
# 187:	total: 1m 32s	remaining: 8m 20s
# 188:	total: 1m 33s	remaining: 8m 19s
# 189:	total: 1m 33s	remaining: 8m 18s
# 190:	test: 0.7510522	best: 0.7510522 (190)	total: 1m 34s	remaining: 8m 18s
# 191:	total: 1m 34s	remaining: 8m 17s
# 192:	total: 1m 35s	remaining: 8m 16s
# 193:	total: 1m 35s	remaining: 8m 15s
# 194:	total: 1m 36s	remaining: 8m 15s
# 195:	test: 0.7512439	best: 0.7512439 (195)	total: 1m 36s	remaining: 8m 14s
# 196:	total: 1m 36s	remaining: 8m 13s
# 197:	total: 1m 37s	remaining: 8m 12s
# 198:	total: 1m 37s	remaining: 8m 12s
# 199:	total: 1m 38s	remaining: 8m 11s
# 200:	test: 0.7514381	best: 0.7514381 (200)	total: 1m 38s	remaining: 8m 10s
# 201:	total: 1m 39s	remaining: 8m 9s
# 202:	total: 1m 39s	remaining: 8m 8s
# 203:	total: 1m 40s	remaining: 8m 8s
# 204:	total: 1m 40s	remaining: 8m 7s
# 205:	test: 0.7514525	best: 0.7514746 (202)	total: 1m 40s	remaining: 8m 6s
# 206:	total: 1m 41s	remaining: 8m 6s
# 207:	total: 1m 41s	remaining: 8m 5s
# 208:	total: 1m 42s	remaining: 8m 4s
# 209:	total: 1m 42s	remaining: 8m 3s
# 210:	test: 0.7515754	best: 0.7516108 (208)	total: 1m 43s	remaining: 8m 3s
# 211:	total: 1m 43s	remaining: 8m 2s
# 212:	total: 1m 44s	remaining: 8m 1s
# 213:	total: 1m 44s	remaining: 8m 1s
# 214:	total: 1m 44s	remaining: 8m
# 215:	test: 0.7515803	best: 0.7516817 (212)	total: 1m 45s	remaining: 7m 59s
# 216:	total: 1m 45s	remaining: 7m 59s
# 217:	total: 1m 46s	remaining: 7m 58s
# 218:	total: 1m 46s	remaining: 7m 57s
# 219:	total: 1m 47s	remaining: 7m 56s
# 220:	test: 0.7517255	best: 0.7517255 (220)	total: 1m 47s	remaining: 7m 56s
# 221:	total: 1m 47s	remaining: 7m 55s
# 222:	total: 1m 48s	remaining: 7m 54s
# 223:	total: 1m 48s	remaining: 7m 54s
# 224:	total: 1m 49s	remaining: 7m 53s
# 225:	test: 0.7516609	best: 0.7517255 (220)	total: 1m 49s	remaining: 7m 52s
# 226:	total: 1m 50s	remaining: 7m 52s
# 227:	total: 1m 50s	remaining: 7m 51s
# 228:	total: 1m 51s	remaining: 7m 50s
# 229:	total: 1m 51s	remaining: 7m 50s
# 230:	test: 0.7518276	best: 0.7518276 (230)	total: 1m 51s	remaining: 7m 49s
# 231:	total: 1m 52s	remaining: 7m 49s
# 232:	total: 1m 52s	remaining: 7m 48s
# 233:	total: 1m 53s	remaining: 7m 47s
# 234:	total: 1m 53s	remaining: 7m 47s
# 235:	test: 0.7518426	best: 0.7518449 (231)	total: 1m 54s	remaining: 7m 46s
# 236:	total: 1m 54s	remaining: 7m 45s
# 237:	total: 1m 55s	remaining: 7m 44s
# 238:	total: 1m 55s	remaining: 7m 44s
# 239:	total: 1m 55s	remaining: 7m 43s
# 240:	test: 0.7520142	best: 0.7520142 (240)	total: 1m 56s	remaining: 7m 42s
# 241:	total: 1m 56s	remaining: 7m 42s
# 242:	total: 1m 57s	remaining: 7m 41s
# 243:	total: 1m 57s	remaining: 7m 41s
# 244:	total: 1m 58s	remaining: 7m 40s
# 245:	test: 0.7519890	best: 0.7520142 (240)	total: 1m 58s	remaining: 7m 39s
# 246:	total: 1m 58s	remaining: 7m 39s
# 247:	total: 1m 59s	remaining: 7m 38s
# 248:	total: 1m 59s	remaining: 7m 37s
# 249:	total: 2m	remaining: 7m 36s
# 250:	test: 0.7519621	best: 0.7520215 (246)	total: 2m	remaining: 7m 36s
# 251:	total: 2m 1s	remaining: 7m 35s
# 252:	total: 2m 1s	remaining: 7m 34s
# 253:	total: 2m 1s	remaining: 7m 34s
# 254:	total: 2m 2s	remaining: 7m 33s
# 255:	test: 0.7517273	best: 0.7520215 (246)	total: 2m 2s	remaining: 7m 33s
# 256:	total: 2m 3s	remaining: 7m 32s
# 257:	total: 2m 3s	remaining: 7m 31s
# 258:	total: 2m 4s	remaining: 7m 31s
# 259:	total: 2m 4s	remaining: 7m 30s
# 260:	test: 0.7517466	best: 0.7520215 (246)	total: 2m 5s	remaining: 7m 29s
# 261:	total: 2m 5s	remaining: 7m 29s
# 262:	total: 2m 5s	remaining: 7m 28s
# 263:	total: 2m 6s	remaining: 7m 27s
# 264:	total: 2m 6s	remaining: 7m 27s
# 265:	test: 0.7520222	best: 0.7520222 (265)	total: 2m 7s	remaining: 7m 26s
# 266:	total: 2m 7s	remaining: 7m 26s
# 267:	total: 2m 8s	remaining: 7m 25s
# 268:	total: 2m 8s	remaining: 7m 25s
# 269:	total: 2m 9s	remaining: 7m 24s
# 270:	test: 0.7521139	best: 0.7521767 (268)	total: 2m 9s	remaining: 7m 23s
# 271:	total: 2m 9s	remaining: 7m 23s
# 272:	total: 2m 10s	remaining: 7m 22s
# 273:	total: 2m 10s	remaining: 7m 21s
# 274:	total: 2m 11s	remaining: 7m 21s
# 275:	test: 0.7521557	best: 0.7521767 (268)	total: 2m 11s	remaining: 7m 20s
# 276:	total: 2m 12s	remaining: 7m 20s
# 277:	total: 2m 12s	remaining: 7m 19s
# 278:	total: 2m 12s	remaining: 7m 18s
# 279:	total: 2m 13s	remaining: 7m 18s
# 280:	test: 0.7522810	best: 0.7522912 (278)	total: 2m 13s	remaining: 7m 17s
# 281:	total: 2m 14s	remaining: 7m 17s
# 282:	total: 2m 14s	remaining: 7m 16s
# 283:	total: 2m 15s	remaining: 7m 16s
# 284:	total: 2m 15s	remaining: 7m 15s
# 285:	test: 0.7523733	best: 0.7523733 (285)	total: 2m 16s	remaining: 7m 14s
# 286:	total: 2m 16s	remaining: 7m 14s
# 287:	total: 2m 16s	remaining: 7m 13s
# 288:	total: 2m 17s	remaining: 7m 13s
# 289:	total: 2m 17s	remaining: 7m 12s
# 290:	test: 0.7525156	best: 0.7525156 (290)	total: 2m 18s	remaining: 7m 12s
# 291:	total: 2m 18s	remaining: 7m 11s
# 292:	total: 2m 19s	remaining: 7m 10s
# 293:	total: 2m 19s	remaining: 7m 10s
# 294:	total: 2m 20s	remaining: 7m 9s
# 295:	test: 0.7524487	best: 0.7525156 (290)	total: 2m 20s	remaining: 7m 9s
# 296:	total: 2m 21s	remaining: 7m 8s
# 297:	total: 2m 21s	remaining: 7m 8s
# 298:	total: 2m 21s	remaining: 7m 7s
# 299:	total: 2m 22s	remaining: 7m 7s
# 300:	test: 0.7524500	best: 0.7525264 (299)	total: 2m 22s	remaining: 7m 6s
# 301:	total: 2m 23s	remaining: 7m 6s
# 302:	total: 2m 23s	remaining: 7m 5s
# 303:	total: 2m 24s	remaining: 7m 5s
# 304:	total: 2m 24s	remaining: 7m 4s
# 305:	test: 0.7524136	best: 0.7525264 (299)	total: 2m 25s	remaining: 7m 3s
# 306:	total: 2m 25s	remaining: 7m 3s
# 307:	total: 2m 25s	remaining: 7m 2s
# 308:	total: 2m 26s	remaining: 7m 2s
# 309:	total: 2m 26s	remaining: 7m 1s
# 310:	test: 0.7522840	best: 0.7525264 (299)	total: 2m 27s	remaining: 7m 1s
# 311:	total: 2m 27s	remaining: 7m
# 312:	total: 2m 28s	remaining: 6m 59s
# 313:	total: 2m 28s	remaining: 6m 59s
# 314:	total: 2m 29s	remaining: 6m 58s
# 315:	test: 0.7524405	best: 0.7525264 (299)	total: 2m 29s	remaining: 6m 58s
# 316:	total: 2m 29s	remaining: 6m 57s
# 317:	total: 2m 30s	remaining: 6m 57s
# 318:	total: 2m 30s	remaining: 6m 56s
# 319:	total: 2m 31s	remaining: 6m 55s
# 320:	test: 0.7522675	best: 0.7525264 (299)	total: 2m 31s	remaining: 6m 55s
# 321:	total: 2m 32s	remaining: 6m 54s
# 322:	total: 2m 32s	remaining: 6m 54s
# 323:	total: 2m 33s	remaining: 6m 53s
# 324:	total: 2m 33s	remaining: 6m 53s
# 325:	test: 0.7523464	best: 0.7525264 (299)	total: 2m 33s	remaining: 6m 52s
# 326:	total: 2m 34s	remaining: 6m 51s
# 327:	total: 2m 34s	remaining: 6m 51s
# 328:	total: 2m 35s	remaining: 6m 50s
# 329:	total: 2m 35s	remaining: 6m 50s
# 330:	test: 0.7523891	best: 0.7525264 (299)	total: 2m 36s	remaining: 6m 49s
# 331:	total: 2m 36s	remaining: 6m 49s
# 332:	total: 2m 37s	remaining: 6m 48s
# 333:	total: 2m 37s	remaining: 6m 48s
# 334:	total: 2m 37s	remaining: 6m 47s
# 335:	test: 0.7523884	best: 0.7525264 (299)	total: 2m 38s	remaining: 6m 47s
# 336:	total: 2m 38s	remaining: 6m 46s
# 337:	total: 2m 39s	remaining: 6m 46s
# 338:	total: 2m 39s	remaining: 6m 45s
# 339:	total: 2m 40s	remaining: 6m 45s
# 340:	test: 0.7523870	best: 0.7525264 (299)	total: 2m 40s	remaining: 6m 44s
# 341:	total: 2m 41s	remaining: 6m 44s
# 342:	total: 2m 41s	remaining: 6m 43s
# 343:	total: 2m 41s	remaining: 6m 43s
# 344:	total: 2m 42s	remaining: 6m 42s
# 345:	test: 0.7522598	best: 0.7525264 (299)	total: 2m 42s	remaining: 6m 41s
# 346:	total: 2m 43s	remaining: 6m 41s
# 347:	total: 2m 43s	remaining: 6m 40s
# 348:	total: 2m 44s	remaining: 6m 40s
# 349:	total: 2m 44s	remaining: 6m 39s
# bestTest = 0.7525264025
# bestIteration = 299
# Shrink model to first 300 iterations.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [12:43:01] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# # Part - 2

# %%
! python /kaggle/usr/lib/part_2_py/part_2_py.py
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.836638
# [200]	valid_0's auc: 0.844823
# [300]	valid_0's auc: 0.847876
# [400]	valid_0's auc: 0.849418
# [500]	valid_0's auc: 0.85032
# [600]	valid_0's auc: 0.850996
# [700]	valid_0's auc: 0.851362
# [800]	valid_0's auc: 0.851475
# [900]	valid_0's auc: 0.851694
# [1000]	valid_0's auc: 0.851807
# [1100]	valid_0's auc: 0.851829
# Early stopping, best iteration is:
# [1052]	valid_0's auc: 0.851872
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.837335
# [200]	valid_0's auc: 0.846088
# [300]	valid_0's auc: 0.849366
# [400]	valid_0's auc: 0.851056
# [500]	valid_0's auc: 0.852019
# [600]	valid_0's auc: 0.852534
# [700]	valid_0's auc: 0.852928
# [800]	valid_0's auc: 0.853154
# [900]	valid_0's auc: 0.853294
# [1000]	valid_0's auc: 0.853486
# [1100]	valid_0's auc: 0.853602
# [1200]	valid_0's auc: 0.853728
# [1300]	valid_0's auc: 0.853707
# Early stopping, best iteration is:
# [1237]	valid_0's auc: 0.853785
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.841177
# [200]	valid_0's auc: 0.849593
# [300]	valid_0's auc: 0.853036
# [400]	valid_0's auc: 0.85491
# [500]	valid_0's auc: 0.855993
# [600]	valid_0's auc: 0.856613
# [700]	valid_0's auc: 0.85702
# [800]	valid_0's auc: 0.857292
# [900]	valid_0's auc: 0.857619
# [1000]	valid_0's auc: 0.857649
# [1100]	valid_0's auc: 0.857687
# [1200]	valid_0's auc: 0.857807
# [1300]	valid_0's auc: 0.857832
# Early stopping, best iteration is:
# [1239]	valid_0's auc: 0.857878
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.841699
# [200]	valid_0's auc: 0.850008
# [300]	valid_0's auc: 0.853213
# [400]	valid_0's auc: 0.854902
# [500]	valid_0's auc: 0.856078
# [600]	valid_0's auc: 0.856647
# [700]	valid_0's auc: 0.857034
# [800]	valid_0's auc: 0.857321
# [900]	valid_0's auc: 0.85759
# Early stopping, best iteration is:
# [892]	valid_0's auc: 0.857606
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.836917
# [200]	valid_0's auc: 0.845292
# [300]	valid_0's auc: 0.849147
# [400]	valid_0's auc: 0.850876
# [500]	valid_0's auc: 0.851871
# [600]	valid_0's auc: 0.852437
# [700]	valid_0's auc: 0.852752
# [800]	valid_0's auc: 0.852972
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.85301
# CV AUC scores:  [0.8518718995128308, 0.8537853827132524, 0.8578779370603279, 0.8576063812203918, 0.8530098299723661]
# Maximum CV AUC score:  0.8578779370603279

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# # Part - 3

# %%
# !python -m pip install --no-index --find-links=/kaggle/input/autogluon-pkgs autogluon > /dev/null
# !python -m pip install --no-index --find-links=/kaggle/input/ray-pkgs --upgrade --force-reinstall -q ray==2.6.3
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires scikit-image>=0.21.0, but you have scikit-image 0.20.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-pubsub 2.19.0 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.51.1 which is incompatible.
# jupyter-events 0.9.0 requires jsonschema[format-nongpl]>=4.18.0, but you have jsonschema 4.17.3 which is incompatible.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-server 2.25.2 requires jsonschema>=4.18.0, but you have jsonschema 4.17.3 which is incompatible.
# jupyterlab-server 2.25.2 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.31.0 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires pydantic>=2, but you have pydantic 1.10.14 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires scikit-image>=0.21.0, but you have scikit-image 0.20.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires protobuf<4,>3.12.2, but you have protobuf 4.25.2 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# autogluon-multimodal 1.0.0 requires jsonschema<4.18,>=4.14, but you have jsonschema 4.21.1 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# botocore 1.34.69 requires urllib3!=2.2.0,<3,>=1.25.4; python_version >= "3.10", but you have urllib3 2.2.0 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# google-cloud-bigquery 2.34.4 requires protobuf<4.0.0dev,>=3.12.0, but you have protobuf 4.25.2 which is incompatible.
# google-cloud-bigtable 1.7.3 requires protobuf<4.0.0dev, but you have protobuf 4.25.2 which is incompatible.
# google-cloud-vision 2.8.0 requires protobuf<4.0.0dev,>=3.19.0, but you have protobuf 4.25.2 which is incompatible.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.31.0 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.5.0 requires protobuf<4,>=3.13.0, but you have protobuf 4.25.2 which is incompatible.
# kfp 2.5.0 requires urllib3<2.0.0, but you have urllib3 2.2.0 which is incompatible.
# kfp-pipeline-spec 0.2.2 requires protobuf<4,>=3.13.0, but you have protobuf 4.25.2 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# openxlab 0.0.34 requires requests~=2.28.2, but you have requests 2.31.0 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# pylibraft 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.25.2 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# tensorflow-metadata 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.25.2 which is incompatible.
# tensorflow-transform 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.25.2 which is incompatible.
# tensorstore 0.1.56 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires pydantic>=2, but you have pydantic 1.10.14 which is incompatible.

# %%
# !python /kaggle/usr/lib/part_3_py/part_3_py.py
# Out:
# train data shape:	 (1526659, 528)
# train data shape:	 (1526659, 341)
# (1526659, 341)
# Memory usage of dataframe is 3107.00 MB
# Memory usage after optimization is: 1055.59 MB
# Decreased by 66.0%
# df_train.shape : (1526659, 341) --> (500, 341)
# WARNING: Could not find version file at "/kaggle/input/home-credit-automl-model-files/predictor/__version__".
# This means that the predictor was fit in a version `<=0.3.1`.
# test data shape:	 (10, 527)
# (10, 527)
# Memory usage of dataframe is 0.04 MB
# Memory usage after optimization is: 0.03 MB
# Decreased by 23.5%
# WARNING: Int features without null values at train time contain null values at inference time! Imputing nulls to 0. To avoid this, pass the features as floats during fit!
# WARNING: Int features with nulls: ['max_birth_259D', 'max_num_group1_8']
# Check null:  False

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# # Part - 4

# %%
# !pip install --force-reinstall scikit-learn --no-index --find-links=file:///kaggle/input/scikit-learn-1-4-0/
# Out:
# Looking in links: file:///kaggle/input/scikit-learn-1-4-0/
# Processing /kaggle/input/scikit-learn-1-4-0/scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Processing /kaggle/input/scikit-learn-1-4-0/numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from scikit-learn)
# Processing /kaggle/input/scikit-learn-1-4-0/scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from scikit-learn)
# Processing /kaggle/input/scikit-learn-1-4-0/joblib-1.3.2-py3-none-any.whl (from scikit-learn)
# Processing /kaggle/input/scikit-learn-1-4-0/threadpoolctl-3.2.0-py3-none-any.whl (from scikit-learn)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.2.0
#     Uninstalling threadpoolctl-3.2.0:
#       Successfully uninstalled threadpoolctl-3.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.0
#     Uninstalling joblib-1.4.0:
#       Successfully uninstalled joblib-1.4.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.0
#     Uninstalling scikit-learn-1.4.0:
#       Successfully uninstalled scikit-learn-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires scikit-image>=0.21.0, but you have scikit-image 0.20.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires protobuf<4,>3.12.2, but you have protobuf 4.21.12 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# autogluon-multimodal 1.0.0 requires jsonschema<4.18,>=4.14, but you have jsonschema 4.21.1 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# kaggle-environments 1.14.3 requires transformers>=4.33.1, but you have transformers 4.31.0 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# pylibraft 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# tensorflow-transform 0.14.0 requires protobuf<4,>=3.7, but you have protobuf 4.21.12 which is incompatible.
# tensorstore 0.1.56 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires pydantic>=2, but you have pydantic 1.10.14 which is incompatible.
# ydata-profiling 4.6.4 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# Successfully installed joblib-1.3.2 numpy-1.26.4 scikit-learn-1.4.0 scipy-1.12.0 threadpoolctl-3.2.0

# %%
# !python /kaggle/usr/lib/part_4_py/part_4_py.py
# Out:
# sys:1: CategoricalRemappingWarning: Local categoricals have different encodings, expensive re-encoding is done to perform this merge operation. Consider using a StringCache or an Enum type if the categories are known in advance
# Memory usage of dataframe is 1168.76 MB
# Memory usage of dataframe became 1160.02 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1526659 entries, 0 to 2703454
# Columns: 196 entries, MONTH to thirdquarter_1082L
# dtypes: bool(1), category(28), float32(164), int32(1), int8(2)
# memory usage: 1013.3 MB
# [CV] END ......................................., score=0.796 total time=  51.2s
# [CV] END ......................................., score=0.800 total time=  47.2s
# [CV] END ......................................., score=0.803 total time=  45.8s
# [CV] END ......................................., score=0.804 total time=  50.3s
# [CV] END ......................................., score=0.800 total time=  45.8s
# AUC: 0.801 +-0.003
# Memory usage of dataframe is 0.01 MB
# Memory usage of dataframe became 0.01 MB
# /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:693: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = data[col].cat.set_categories(category)

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# # ensemble

# %%
import pandas as pd
sub_1 = pd.read_csv("submission_1.csv", dtype={"case_id": int}).set_index("case_id")
sub_2 = pd.read_csv("submission_2.csv", dtype={"case_id": int}).set_index("case_id")
sub_3 = pd.read_csv("submission_3.csv", dtype={"case_id": int}).set_index("case_id")
sub_4 = pd.read_csv("submission_4.csv", dtype={"case_id": int}).set_index("case_id")

# %%
sub = 0.4*sub_3 + 0.6*(0.98*sub_2 + 0.02*(0.8*sub_4 + 0.2*sub_1))

# %%
test = pd.read_csv("/kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_base.csv")
SHIFT = 0.025
week_num = list(test["WEEK_NUM"])
sub["WEEK_NUM"] = week_num
condition = sub["WEEK_NUM"] < (sub["WEEK_NUM"].max() - sub["WEEK_NUM"].min())/2 + sub["WEEK_NUM"].min()
sub.loc[condition, 'score'] = (sub.loc[condition, 'score'] - SHIFT).clip(0)
del sub["WEEK_NUM"]
sub.to_csv("submission.csv")
